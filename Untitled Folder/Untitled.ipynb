# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader import data as wb

# %%
pg = wb.DataReader('MSFT', data_source='yahoo', start= '1/1/2000')

# %%
pg['simple return'] = ((pg['Adj Close']/pg['Adj Close'].shift(1)) - 1) * 100

# %%
pg.head()
# Out:
#                High      Low      Open     Close      Volume  Adj Close  \
# Date
# 1999-12-31  58.8750  58.1250  58.75000  58.37500  12517600.0  37.259617
# 2000-01-03  59.3125  56.0000  58.68750  58.28125  53228400.0  37.199776
# 2000-01-04  58.5625  56.1250  56.78125  56.31250  54119000.0  35.943153
# 2000-01-05  58.1875  54.6875  55.56250  56.90625  64059600.0  36.322121
# 2000-01-06  56.9375  54.1875  56.09375  55.00000  54976600.0  35.105415
#
#             simple return
# Date
# 1999-12-31            NaN
# 2000-01-03      -0.160606
# 2000-01-04      -3.378037
# 2000-01-05       1.054352
# 2000-01-06      -3.349764

# %%
pg['simple return'].plot()
plt.show()

# %%
a = pg['simple return'].mean() * 250

# %%
print(a)
# Out:
# 13.128712837691694

# %%
pg['log'] = np.log(pg['Adj Close']/pg['Adj Close'].shift(1))*100

# %%
pg.head()
# Out:
#                High      Low      Open     Close      Volume  Adj Close  \
# Date
# 1999-12-31  58.8750  58.1250  58.75000  58.37500  12517600.0  37.259617
# 2000-01-03  59.3125  56.0000  58.68750  58.28125  53228400.0  37.199776
# 2000-01-04  58.5625  56.1250  56.78125  56.31250  54119000.0  35.943153
# 2000-01-05  58.1875  54.6875  55.56250  56.90625  64059600.0  36.322121
# 2000-01-06  56.9375  54.1875  56.09375  55.00000  54976600.0  35.105415
#
#             simple return       log
# Date
# 1999-12-31            NaN       NaN
# 2000-01-03      -0.160606 -0.160735
# 2000-01-04      -3.378037 -3.436411
# 2000-01-05       1.054352  1.048832
# 2000-01-06      -3.349764 -3.407154

# %%
pg['log'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print(pg['log'].mean()*250)
# Out:
# 8.373033187081079
